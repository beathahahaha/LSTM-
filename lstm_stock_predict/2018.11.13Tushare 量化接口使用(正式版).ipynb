# %%
import tushare as ts
print("start")
d=ts.get_h_data('600036',start='2008-01-01',end='2018-01-01',autype='hfq')
print(d)
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\招商银行600036.csv",columns=['open','close','high','low','volume'])

#print(data['open'])
print("over")
# Out:
# start
# [Getting data:]####timed out
# ####################################              open    high   close     low       volume        amount
# date
# 2017-12-29  133.67  135.58  135.49  133.58   32904289.0  9.509645e+08
# 2017-12-28  134.23  135.02  133.67  132.83   42120227.0  1.209920e+09
# 2017-12-27  137.73  139.04  134.28  133.44   63393214.0  1.845505e+09
# 2017-12-26  136.43  139.13  138.71  136.38   61399980.0  1.817412e+09
# 2017-12-25  136.28  139.93  136.75  135.96   60107575.0  1.777969e+09
# 2017-12-22  137.78  138.39  136.75  136.15   44313847.0  1.301574e+09
# 2017-12-21  137.12  140.07  138.39  136.33   56738026.0  1.684770e+09
# 2017-12-20  137.31  138.90  137.59  135.77   55439985.0  1.631568e+09
# 2017-12-19  132.92  137.73  137.08  132.32   77123200.0  2.238123e+09
# 2017-12-18  131.20  133.11  132.27  130.96   37389497.0  1.058597e+09
# 2017-12-15  133.39  133.53  131.01  130.73   48806521.0  1.378078e+09
# ...

# %%
import tushare as ts
print("start")
d=ts.get_h_data('601328',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\交通银行601328.csv",columns=['open','close','high','low','volume']) #自行修改路径名字

print("over")
# Out:
# start
# [Getting data:]HTTP Error 456:
# HTTP Error 456:
# HTTP Error 456:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-ed243fc194f0> in <module>()
#       1 import tushare as ts
#       2 print("start")
# ----> 3 d=ts.get_h_data('601328',start='2008-01-01',end='2018-01-01',autype='hfq')
#       4 d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\交通银行601328.csv",columns=['open','close','high','low','volume'])
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\tushare\stock\trading.py in get_h_data(code, start, end, autype, index, retry_count, pause, drop_factor)
#     430     ct._write_head()
#     431     data = _parse_fq_data(_get_index_url(index, code, qt), index,
# --> 432                           retry_count, pause)
#     433     if data is None:
#     434         data = pd.DataFrame()
#
# ...

# %%
import tushare as ts
print("start")
d=ts.get_h_data('601998',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\中信银行601998.csv",columns=['open','close','high','low','volume'])
print("over")
# Out:
# start
# [Getting data:]########################################HTTP Error 456:
# over

# %%
import tushare as ts
print("start")
d=ts.get_h_data('601398',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\工商银行601398.csv",columns=['open','close','high','low','volume'])
print(d)
print("over")
# Out:
# start
# [Getting data:]########################################             open   high  close    low       volume        amount
# date
# 2017-12-29   9.99  10.14  10.11   9.98  216899773.0  1.340017e+09
# 2017-12-28   9.83  10.01  10.01   9.81  210088644.0  1.281418e+09
# 2017-12-27   9.93  10.03   9.86   9.81  215140064.0  1.310856e+09
# 2017-12-26   9.78   9.95   9.91   9.75  216532909.0  1.313822e+09
# 2017-12-25   9.67   9.83   9.78   9.67  239636448.0  1.437036e+09
# 2017-12-22   9.73   9.75   9.65   9.65  118660402.0  7.049594e+08
# 2017-12-21   9.73   9.77   9.72   9.69  146581853.0  8.747448e+08
# 2017-12-20   9.77   9.83   9.73   9.69  190041016.0  1.136206e+09
# 2017-12-19   9.62   9.78   9.75   9.60  272821569.0  1.628203e+09
# 2017-12-18   9.55   9.65   9.65   9.54  167000651.0  9.832050e+08
# 2017-12-15   9.59   9.60   9.54   9.51  116848154.0  6.844168e+08
# 2017-12-14   9.62   9.73   9.60   9.59  146937837.0  8.700539e+08
# ...

# %%
import tushare as ts
print("start")
d=ts.get_h_data('601398',start='2008-01-01',end='2018-01-01',autype='hfq')
#d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\工商银行601398.csv",columns=['open','close','high','low','volume'])
print(d)
print("over")
# Out:
# start
# [Getting data:]########################################Empty DataFrame
# Columns: []
# Index: []
# over

# %%
import tushare as ts
print("start")
d=ts.get_h_data('601328',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\交通银行601328.csv",columns=['open','close','high','low','volume'])

print("over")

import tushare as ts
print("start")
d=ts.get_h_data('601998',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\中信银行601998.csv",columns=['open','close','high','low','volume'])
print("over")

import tushare as ts
print("start")
d=ts.get_h_data('601389',start='2008-01-01',end='2018-01-01',autype='hfq')
d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\工商银行601389.csv",columns=['open','close','high','low','volume'])
print("over")
# Out:
# start
# [Getting data:]########################################over
# start
# [Getting data:]#####HTTP Error 456:
# ##HTTP Error 456:
# HTTP Error 456:
# HTTP Error 456:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-84d9204e918c> in <module>()
#       8 import tushare as ts
#       9 print("start")
# ---> 10 d=ts.get_h_data('601998',start='2008-01-01',end='2018-01-01',autype='hfq')
#      11 d.to_csv(r"C:\Users\Lenovo\Desktop\学习日记\中信银行601998.csv",columns=['open','close','high','low','volume'])
#      12 print("over")
#
# C:\ProgramData\Anaconda3\lib\site-packages\tushare\stock\trading.py in get_h_data(code, start, end, autype, index, retry_count, pause, drop_factor)
#     438             ct._write_console()
#     439             df = _parse_fq_data(_get_index_url(index, code, qt), index,
# --> 440                                 retry_count, pause)
# ...

# %%
ts.get_h_data('399106', index=True) #深圳综合指数
# Out:
# [Getting data:]HTTP Error 456:
# HTTP Error 456:
# HTTP Error 456:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-c462765807a1> in <module>()
# ----> 1 ts.get_h_data('399106', index=True) #深圳综合指数
#
# C:\ProgramData\Anaconda3\lib\site-packages\tushare\stock\trading.py in get_h_data(code, start, end, autype, index, retry_count, pause, drop_factor)
#     430     ct._write_head()
#     431     data = _parse_fq_data(_get_index_url(index, code, qt), index,
# --> 432                           retry_count, pause)
#     433     if data is None:
#     434         data = pd.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tushare\stock\trading.py in _parse_fq_data(url, index, retry_count, pause)
#     570         else:
#     571             return df
# --> 572     raise IOError(ct.NETWORK_URL_ERROR_MSG)
#     573
#     574
#
# OSError: 获取失败，请检查网络.

# %%
ts.get_hist_data('600848', ktype='W') #获取周k线数据
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# date
# 2018-11-13  20.12  20.46  20.27  19.70       0.0         -0.23     -1.12
# 2018-11-09  18.30  22.18  20.50  18.18       0.0          2.56     14.27
# 2018-11-02  17.02  17.95  17.94  16.84       0.0          0.66      3.82
# 2018-10-26  16.18  17.67  17.28  16.16       0.0          1.10      6.80
# 2018-10-19  17.83  18.75  16.18  14.76       0.0         -1.65     -9.25
# 2018-10-12  19.50  20.50  17.83  16.15       0.0         -3.85    -17.76
# 2018-06-14  22.01  22.16  21.68  21.56       0.0         -0.32     -1.46
# 2018-06-08  21.82  23.23  22.00  21.53       0.0          0.27      1.24
# 2018-06-01  23.32  23.24  21.73  21.61       0.0         -2.04     -8.58
# 2018-05-25  23.99  25.00  23.77  23.26       0.0         -0.02     -0.08
# 2018-05-18  23.59  25.60  23.79  23.21       0.0          0.18      0.76
# 2018-05-11  23.50  23.95  23.61  23.10       0.0          0.15      0.64
# ...
